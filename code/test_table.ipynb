# %% [markdown]
# # Test HAIL table creation from JSON files

# %%
import hail as hl
import pandas as pd
hl.init()

# Load your table
ht = hl.read_table("../data/teste/json_variants.ht")
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c6124196-b2ee-4f7d-b573-eb47b5e2e981">Loading BokehJS ...</span>
#     </div>
# 25/11/19 14:26:24 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Running on Apache Spark version 3.5.7
# SparkUI available at http://pimenta:4041
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.136-c32f88309ab0
# LOGGING: writing to /home/matheus/Documents/gnomeAD-tb/code/hail-20251119-1426-0.2.136-c32f88309ab0.log

# %%
# Quick checks
print(f"Total variants: {ht.count()}")
print(f"Chromosomes: {ht.aggregate(hl.agg.collect_as_set(ht.chromosome))}")
print(f"Fields: {list(ht.row)}")

# Look at first few rows
ht.show(20)

# Get summary statistics
ht.describe()
# Out:
# Total variants: 30487
# [Stage 0:=======================================>                (59 + 12) / 84]
# Chromosomes: {'chr12', 'chr2', 'chr7', 'chrX', 'chr8', 'chr9', 'chr17', 'chr11', 'chr15', 'chr18', 'chr14', 'chr5', 'chrY', 'chr22', 'chr1', 'chr3', 'chr10', 'chr16', 'chr19', 'chr20', 'chr21', 'chr13', 'chr4', 'chr6'}
# Fields: ['chromosome', 'position', 'ref', 'alt', 'vid', 'hgvsg', 'variant_type', 'begin', 'end', 'filters', 'mapping_quality', 'fisher_strand_bias', 'quality', 'cytogenetic_band', 'phylop_score', 'phylop_primate_score', 'gerp_score', 'dann_score', 'rsid', 'gnomad_af', 'gnomad_ac', 'gnomad_an', 'gnomad_hc', 'gnomad_afr_af', 'gnomad_amr_af', 'gnomad_eas_af', 'gnomad_fin_af', 'gnomad_nfe_af', 'gnomad_asj_af', 'gnomad_sas_af', 'gnomad_oth_af', 'gnomad_failed_filter', 'gnomad_exome_af', 'gnomad_exome_ac', 'gnomad_exome_an', 'gnomad_exome_hc', 'gnomad_exome_failed_filter', 'topmed_af', 'topmed_ac', 'topmed_an', 'topmed_hc', 'topmed_failed_filter', 'clinvar_variant_type', 'clinvar_significance', 'clinvar_id', 'n_transcripts', 'transcripts', 'samples', 'locus', 'alleles', 'max_gnomad_af', 'max_pop_af', 'canonical_transcript', 'all_consequences', 'genes']
# +------------+----------+-----+-----+----------------+
# | chromosome | position | ref | alt | vid            |
# +------------+----------+-----+-----+----------------+
# | str        |    int32 | str | str | str            |
# +------------+----------+-----+-----+----------------+
# | "chr1"     |    69081 | "G" | "C" | "1-69081-G-C"  |
# | "chr1"     |    69270 | "A" | "G" | "1-69270-A-G"  |
# | "chr1"     |    69511 | "A" | "G" | "1-69511-A-G"  |
# | "chr1"     |    69897 | "T" | "C" | "1-69897-T-C"  |
# | "chr1"     |   358121 | "C" | "T" | "1-358121-C-T" |
# | "chr1"     |   373232 | "G" | "A" | "1-373232-G-A" |
# | "chr1"     |   924024 | "C" | "G" | "1-924024-C-G" |
# | "chr1"     |   924310 | "C" | "G" | "1-924310-C-G" |
# | "chr1"     |   924321 | "C" | "G" | "1-924321-C-G" |
# | "chr1"     |   924533 | "A" | "G" | "1-924533-A-G" |
# | "chr1"     |   942451 | "T" | "C" | "1-942451-T-C" |
# | "chr1"     |   946247 | "G" | "A" | "1-946247-G-A" |
# | "chr1"     |   952421 | "A" | "G" | "1-952421-A-G" |
# | "chr1"     |   953259 | "T" | "C" | "1-953259-T-C" |
# | "chr1"     |   953279 | "T" | "C" | "1-953279-T-C" |
# | "chr1"     |   961945 | "G" | "C" | "1-961945-G-C" |
# | "chr1"     |   965125 | "G" | "C" | "1-965125-G-C" |
# | "chr1"     |   966227 | "C" | "G" | "1-966227-C-G" |
# | "chr1"     |   966272 | "A" | "G" | "1-966272-A-G" |
# | "chr1"     |   970892 | "A" | "C" | "1-970892-A-C" |
# +------------+----------+-----+-----+----------------+
#
# +----------------------------+--------------+--------+--------+---------+
# | hgvsg                      | variant_type |  begin |    end | filters |
# +----------------------------+--------------+--------+--------+---------+
# | str                        | str          |  int32 |  int32 | str     |
# +----------------------------+--------------+--------+--------+---------+
# | "NC_000001.11:g.69081G>C"  | "SNV"        |  69081 |  69081 | "PASS"  |
# | "NC_000001.11:g.69270A>G"  | "SNV"        |  69270 |  69270 | "PASS"  |
# | "NC_000001.11:g.69511A>G"  | "SNV"        |  69511 |  69511 | "PASS"  |
# | "NC_000001.11:g.69897T>C"  | "SNV"        |  69897 |  69897 | "PASS"  |
# | "NC_000001.11:g.358121C>T" | "SNV"        | 358121 | 358121 | "PASS"  |
# | "NC_000001.11:g.373232G>A" | "SNV"        | 373232 | 373232 | "PASS"  |
# | "NC_000001.11:g.924024C>G" | "SNV"        | 924024 | 924024 | "PASS"  |
# | "NC_000001.11:g.924310C>G" | "SNV"        | 924310 | 924310 | "PASS"  |
# | "NC_000001.11:g.924321C>G" | "SNV"        | 924321 | 924321 | "PASS"  |
# | "NC_000001.11:g.924533A>G" | "SNV"        | 924533 | 924533 | "PASS"  |
# | "NC_000001.11:g.942451T>C" | "SNV"        | 942451 | 942451 | "PASS"  |
# | "NC_000001.11:g.946247G>A" | "SNV"        | 946247 | 946247 | "PASS"  |
# | "NC_000001.11:g.952421A>G" | "SNV"        | 952421 | 952421 | "PASS"  |
# | "NC_000001.11:g.953259T>C" | "SNV"        | 953259 | 953259 | "PASS"  |
# | "NC_000001.11:g.953279T>C" | "SNV"        | 953279 | 953279 | "PASS"  |
# | "NC_000001.11:g.961945G>C" | "SNV"        | 961945 | 961945 | "PASS"  |
# | "NC_000001.11:g.965125G>C" | "SNV"        | 965125 | 965125 | "PASS"  |
# | "NC_000001.11:g.966227C>G" | "SNV"        | 966227 | 966227 | "PASS"  |
# | "NC_000001.11:g.966272A>G" | "SNV"        | 966272 | 966272 | "PASS"  |
# | "NC_000001.11:g.970892A>C" | "SNV"        | 970892 | 970892 | "PASS"  |
# +----------------------------+--------------+--------+--------+---------+
#
# +-----------------+--------------------+---------+------------------+
# | mapping_quality | fisher_strand_bias | quality | cytogenetic_band |
# +-----------------+--------------------+---------+------------------+
# |         float64 |            float64 | float64 | str              |
# +-----------------+--------------------+---------+------------------+
# |        1,29e+01 |                 NA |      NA | "1p36.33"        |
# |        2,22e+01 |                 NA |      NA | "1p36.33"        |
# |        2,98e+01 |                 NA |      NA | "1p36.33"        |
# |        2,03e+01 |                 NA |      NA | "1p36.33"        |
# |        6,60e-01 |                 NA |      NA | "1p36.33"        |
# |        2,18e+00 |                 NA |      NA | "1p36.33"        |
# |        2,50e+02 |                 NA |      NA | "1p36.33"        |
# |        2,49e+02 |                 NA |      NA | "1p36.33"        |
# |        2,49e+02 |                 NA |      NA | "1p36.33"        |
# |        2,48e+02 |                 NA |      NA | "1p36.33"        |
# |        2,50e+02 |                 NA |      NA | "1p36.33"        |
# |        2,40e+02 |                 NA |      NA | "1p36.33"        |
# |        2,43e+02 |                 NA |      NA | "1p36.33"        |
# |        2,34e+02 |                 NA |      NA | "1p36.33"        |
# |        2,38e+02 |                 NA |      NA | "1p36.33"        |
# |        2,50e+02 |                 NA |      NA | "1p36.33"        |
# |        2,50e+02 |                 NA |      NA | "1p36.33"        |
# |        2,49e+02 |                 NA |      NA | "1p36.33"        |
# |        2,50e+02 |                 NA |      NA | "1p36.33"        |
# |        2,50e+02 |                 NA |      NA | "1p36.33"        |
# +-----------------+--------------------+---------+------------------+
#
# +--------------+----------------------+------------+------------+
# | phylop_score | phylop_primate_score | gerp_score | dann_score |
# +--------------+----------------------+------------+------------+
# |      float64 |              float64 |    float64 |    float64 |
# +--------------+----------------------+------------+------------+
# |    -5,00e-01 |            -1,65e+00 |  -5,68e+00 |   3,60e-01 |
# |     8,00e-01 |             1,08e+00 |  -2,89e+00 |   5,80e-01 |
# |    -1,00e-01 |             6,99e-01 |   1,29e+00 |   4,50e-01 |
# |     7,00e-01 |             1,05e+00 |   9,04e-02 |   6,20e-01 |
# |     2,00e-01 |             6,80e-02 |         NA |         NA |
# |     1,00e-01 |            -1,30e+00 |         NA |         NA |
# |    -2,00e-01 |             6,83e-01 |  -1,26e+00 |   4,60e-01 |
# |    -2,00e-01 |             7,88e-01 |  -2,49e+00 |   1,90e-01 |
# |    -2,00e-01 |             2,93e-01 |  -4,70e+00 |   2,20e-01 |
# |    -2,30e+00 |            -3,40e-02 |  -5,19e+00 |   3,40e-01 |
# |    -1,00e-01 |             2,94e-01 |   1,68e-01 |   6,10e-01 |
# |     9,00e-01 |             2,38e-01 |   2,11e+00 |   6,00e-01 |
# |    -1,40e+00 |            -2,02e+00 |  -9,23e+00 |   4,00e-01 |
# |    -7,00e-01 |            -8,16e-01 |  -3,10e-01 |   3,40e-01 |
# |     0,00e+00 |            -2,00e+00 |   2,34e+00 |   2,40e-01 |
# |    -6,00e-01 |            -1,43e+00 |  -6,85e+00 |   7,60e-01 |
# |     1,00e+00 |             7,94e-01 |  -6,48e-01 |   6,40e-01 |
# |    -8,00e-01 |             2,83e-01 |  -3,07e+00 |   4,00e-01 |
# |    -1,00e+00 |             2,18e-01 |         NA |   5,00e-01 |
# |    -1,10e+00 |             2,40e-01 |  -4,06e+00 |   6,20e-01 |
# +--------------+----------------------+------------+------------+
#
# +---------------+-----------+-----------+-----------+-----------+
# | rsid          | gnomad_af | gnomad_ac | gnomad_an | gnomad_hc |
# +---------------+-----------+-----------+-----------+-----------+
# | str           |   float64 |     int32 |     int32 |     int32 |
# +---------------+-----------+-----------+-----------+-----------+
# | "rs747112327" |  8,50e-03 |       186 |     21896 |         5 |
# | "rs201219564" |  6,29e-01 |     13469 |     21428 |      4877 |
# | "rs2691305"   |  8,46e-01 |     70558 |     83430 |     32520 |
# | "rs200676709" |  4,86e-01 |     25259 |     51958 |      5492 |
# | "rs62635555"  |        NA |        NA |        NA |        NA |
# | "rs879956032" |        NA |        NA |        NA |        NA |
# | "rs71509444"  |  7,78e-01 |    116829 |    150098 |     50303 |
# | "rs71509445"  |  7,96e-01 |    118986 |    149408 |     51453 |
# | "rs71509446"  |  7,97e-01 |    118977 |    149372 |     51449 |
# | "rs112703963" |  8,21e-01 |    122759 |    149472 |     53980 |
# | "rs6672356"   |  1,00e+00 |    151999 |    152024 |     75987 |
# | "rs2272757"   |  4,81e-01 |     73207 |    152150 |     21171 |
# | "rs3828047"   |  9,34e-01 |    142232 |    152268 |     66460 |
# | "rs3748596"   |  9,34e-01 |    142255 |    152286 |     66471 |
# | "rs3748597"   |  9,34e-01 |    142266 |    152296 |     66478 |
# | "rs4970441"   |  8,69e-01 |    132265 |    152190 |     58144 |
# | "rs28705211"  |  2,00e-01 |     30381 |    151930 |      3785 |
# | "rs13302996"  |  8,41e-01 |    127882 |    152112 |     55268 |
# | "rs2879814"   |  1,00e+00 |    152276 |    152288 |     76132 |
# | "rs28507236"  |  1,31e-01 |     19877 |    151494 |      1576 |
# +---------------+-----------+-----------+-----------+-----------+
#
# +---------------+---------------+---------------+---------------+
# | gnomad_afr_af | gnomad_amr_af | gnomad_eas_af | gnomad_fin_af |
# +---------------+---------------+---------------+---------------+
# |       float64 |       float64 |       float64 |       float64 |
# +---------------+---------------+---------------+---------------+
# |      2,01e-03 |      1,32e-02 |      0,00e+00 |      3,10e-02 |
# |      3,54e-01 |      6,95e-01 |      9,96e-01 |      9,29e-01 |
# |      5,95e-01 |      8,95e-01 |      1,00e+00 |      9,91e-01 |
# |      2,92e-01 |      4,78e-01 |      6,04e-01 |      6,99e-01 |
# |            NA |            NA |            NA |            NA |
# |            NA |            NA |            NA |            NA |
# |      3,94e-01 |      8,20e-01 |      5,67e-01 |      9,57e-01 |
# |      4,46e-01 |      8,31e-01 |      5,65e-01 |      9,61e-01 |
# |      4,47e-01 |      8,31e-01 |      5,65e-01 |      9,61e-01 |
# |      4,79e-01 |      9,22e-01 |      6,89e-01 |      9,62e-01 |
# |      1,00e+00 |      1,00e+00 |      1,00e+00 |      1,00e+00 |
# |      1,45e-01 |      4,81e-01 |      6,58e-01 |      6,29e-01 |
# |      9,09e-01 |      9,33e-01 |      9,24e-01 |      9,65e-01 |
# |      9,09e-01 |      9,33e-01 |      9,25e-01 |      9,65e-01 |
# |      9,09e-01 |      9,33e-01 |      9,25e-01 |      9,65e-01 |
# |      7,16e-01 |      9,00e-01 |      9,21e-01 |      9,40e-01 |
# |      4,82e-02 |      1,87e-01 |      8,05e-02 |      2,76e-01 |
# |      6,14e-01 |      8,95e-01 |      9,23e-01 |      9,40e-01 |
# |      1,00e+00 |      1,00e+00 |      1,00e+00 |      1,00e+00 |
# |      1,89e-01 |      1,62e-01 |      3,13e-01 |      1,24e-01 |
# +---------------+---------------+---------------+---------------+
#
# +---------------+---------------+---------------+---------------+
# | gnomad_nfe_af | gnomad_asj_af | gnomad_sas_af | gnomad_oth_af |
# +---------------+---------------+---------------+---------------+
# |       float64 |       float64 |       float64 |       float64 |
# +---------------+---------------+---------------+---------------+
# |      2,12e-02 |      2,27e-02 |      5,17e-03 |            NA |
# |      8,80e-01 |      8,03e-01 |      8,93e-01 |            NA |
# |      9,67e-01 |      9,78e-01 |      9,78e-01 |            NA |
# |      6,75e-01 |      6,71e-01 |      6,26e-01 |            NA |
# |            NA |            NA |            NA |            NA |
# |            NA |            NA |            NA |            NA |
# |      9,74e-01 |      9,57e-01 |      8,77e-01 |            NA |
# |      9,79e-01 |      9,64e-01 |      8,80e-01 |            NA |
# |      9,79e-01 |      9,63e-01 |      8,80e-01 |            NA |
# |      9,80e-01 |      9,73e-01 |      9,10e-01 |            NA |
# |      1,00e+00 |      1,00e+00 |      1,00e+00 |            NA |
# |      6,38e-01 |      5,61e-01 |      5,77e-01 |            NA |
# |      9,46e-01 |      9,27e-01 |      9,22e-01 |            NA |
# |      9,46e-01 |      9,27e-01 |      9,22e-01 |            NA |
# |      9,46e-01 |      9,27e-01 |      9,22e-01 |            NA |
# |      9,34e-01 |      9,12e-01 |      9,20e-01 |            NA |
# |      2,78e-01 |      3,22e-01 |      2,86e-01 |            NA |
# |      9,34e-01 |      9,12e-01 |      9,20e-01 |            NA |
# |      1,00e+00 |      1,00e+00 |      1,00e+00 |            NA |
# |      8,22e-02 |      6,79e-02 |      1,08e-01 |            NA |
# +---------------+---------------+---------------+---------------+
#
# +----------------------+-----------------+-----------------+-----------------+
# | gnomad_failed_filter | gnomad_exome_af | gnomad_exome_ac | gnomad_exome_an |
# +----------------------+-----------------+-----------------+-----------------+
# |                 bool |         float64 |           int32 |           int32 |
# +----------------------+-----------------+-----------------+-----------------+
# |                 True |        1,76e-02 |            4788 |          271898 |
# |                 True |        8,78e-01 |          374631 |          426620 |
# |                   NA |        9,62e-01 |          832303 |          865570 |
# |                 True |        7,04e-01 |          209373 |          297420 |
# |                   NA |              NA |              NA |              NA |
# |                   NA |              NA |              NA |              NA |
# |                   NA |        9,44e-01 |              17 |              18 |
# |                   NA |        9,78e-01 |              88 |              90 |
# |                   NA |        9,86e-01 |              69 |              70 |
# |                   NA |        9,54e-01 |             803 |             842 |
# |                   NA |        1,00e+00 |         1335957 |         1336086 |
# |                   NA |        6,21e-01 |          906856 |         1460824 |
# |                   NA |        9,43e-01 |         1377167 |         1461030 |
# |                   NA |        9,43e-01 |         1371615 |         1454022 |
# |                   NA |        9,43e-01 |         1343267 |         1424188 |
# |                   NA |        9,26e-01 |         1352838 |         1460598 |
# |                   NA |        2,64e-01 |          385291 |         1460380 |
# |                   NA |              NA |              NA |              NA |
# |                   NA |              NA |              NA |              NA |
# |                   NA |        9,64e-02 |          140560 |         1458530 |
# +----------------------+-----------------+-----------------+-----------------+
#
# +-----------------+----------------------------+-----------+-----------+
# | gnomad_exome_hc | gnomad_exome_failed_filter | topmed_af | topmed_ac |
# +-----------------+----------------------------+-----------+-----------+
# |           int32 |                       bool |   float64 |     int32 |
# +-----------------+----------------------------+-----------+-----------+
# |             729 |                       True |  8,29e-03 |      1041 |
# |          176537 |                       True |  2,75e-01 |     34480 |
# |          410006 |                       True |  8,75e-01 |    109911 |
# |           78375 |                       True |  2,80e-01 |     35215 |
# |              NA |                         NA |        NA |        NA |
# |              NA |                         NA |        NA |        NA |
# |               8 |                         NA |  7,55e-01 |     94793 |
# |              43 |                         NA |  7,74e-01 |     97178 |
# |              34 |                         NA |  7,74e-01 |     97176 |
# |             383 |                         NA |  7,99e-01 |    100358 |
# |          667915 |                         NA |  1,00e+00 |    125544 |
# |          287297 |                         NA |  4,74e-01 |     59539 |
# |          649156 |                       True |  9,31e-01 |    116947 |
# |          647119 |                         NA |  9,31e-01 |    116961 |
# |          633722 |                       True |  9,31e-01 |    116960 |
# |          627440 |                         NA |  8,61e-01 |    108092 |
# |           52904 |                         NA |  1,89e-01 |     23670 |
# |              NA |                         NA |  8,30e-01 |    104226 |
# |              NA |                         NA |  1,00e+00 |    125560 |
# |            8605 |                         NA |  1,36e-01 |     17131 |
# +-----------------+----------------------------+-----------+-----------+
#
# +-----------+-----------+----------------------+----------------------+
# | topmed_an | topmed_hc | topmed_failed_filter | clinvar_variant_type |
# +-----------+-----------+----------------------+----------------------+
# |     int32 |     int32 |                 bool | str                  |
# +-----------+-----------+----------------------+----------------------+
# |    125568 |         0 |                 True | NA                   |
# |    125568 |        11 |                 True | NA                   |
# |    125568 |     50718 |                 True | NA                   |
# |    125568 |        25 |                 True | NA                   |
# |        NA |        NA |                   NA | NA                   |
# |        NA |        NA |                   NA | NA                   |
# |    125568 |     40119 |                   NA | NA                   |
# |    125568 |     41386 |                   NA | NA                   |
# |    125568 |     41379 |                   NA | NA                   |
# |    125568 |     43389 |                   NA | NA                   |
# |    125568 |     62760 |                   NA | "SNV;SNV"            |
# |    125568 |     17233 |                   NA | NA                   |
# |    125568 |     54474 |                   NA | NA                   |
# |    125568 |     54485 |                   NA | NA                   |
# |    125568 |     54484 |                   NA | NA                   |
# |    125568 |     47111 |                   NA | NA                   |
# |    125568 |      2904 |                   NA | NA                   |
# |    125568 |     44591 |                   NA | NA                   |
# |    125568 |     62776 |                   NA | NA                   |
# |    125568 |      1445 |                   NA | NA                   |
# +-----------+-----------+----------------------+----------------------+
#
# +---------------------------------+---------------------------------+
# | clinvar_significance            | clinvar_id                      |
# +---------------------------------+---------------------------------+
# | str                             | str                             |
# +---------------------------------+---------------------------------+
# | NA                              | NA                              |
# | NA                              | NA                              |
# | NA                              | NA                              |
# | NA                              | NA                              |
# | NA                              | NA                              |
# | NA                              | NA                              |
# | NA                              | NA                              |
# | NA                              | NA                              |
# | NA                              | NA                              |
# | NA                              | NA                              |
# | "Benign;Uncertain significance" | "VCV001166513.9;VCV003249251.1" |
# | NA                              | NA                              |
# | NA                              | NA                              |
# | NA                              | NA                              |
# | NA                              | NA                              |
# | NA                              | NA                              |
# | NA                              | NA                              |
# | NA                              | NA                              |
# | NA                              | NA                              |
# | NA                              | NA                              |
# +---------------------------------+---------------------------------+
#
# +---------------+
# | n_transcripts |
# +---------------+
# |         int32 |
# +---------------+
# |             3 |
# |             2 |
# |             2 |
# |             2 |
# |             4 |
# |             3 |
# |            17 |
# |            17 |
# |            17 |
# |            17 |
# |            22 |
# |            22 |
# |             4 |
# |             5 |
# |             5 |
# |            17 |
# |            12 |
# |            13 |
# |            13 |
# |            17 |
# +---------------+
#
# +------------------------------------------------------------------------------+
# | transcripts                                                                  |
# +------------------------------------------------------------------------------+
# | array<struct{transcript_id: str, source: str, bio_type: str, gene_id: str... |
# +------------------------------------------------------------------------------+
# | [("ENST00000642116.1","Ensembl","lncRNA","ENSG00000290826","ENSG000002908... |
# | [("ENST00000641515.2","Ensembl","mRNA","ENSG00000186092","OR4F5",["synony... |
# | [("ENST00000641515.2","Ensembl","mRNA","ENSG00000186092","OR4F5",["missen... |
# | [("ENST00000641515.2","Ensembl","mRNA","ENSG00000186092","OR4F5",["synony... |
# | [("ENST00000441866.2","Ensembl","lncRNA","ENSG00000228463","ENSG000002284... |
# | [("ENST00000453935.1","Ensembl","lncRNA","ENSG00000290385","ENSG000002903... |
# | [("ENST00000609207.1","Ensembl","lncRNA","ENSG00000223764","LINC02593",["... |
# | [("ENST00000609207.1","Ensembl","lncRNA","ENSG00000223764","LINC02593",["... |
# | [("ENST00000609207.1","Ensembl","lncRNA","ENSG00000223764","LINC02593",["... |
# | [("ENST00000609207.1","Ensembl","lncRNA","ENSG00000223764","LINC02593",["... |
# | [("ENST00000616016.5","Ensembl","mRNA","ENSG00000187634","SAMD11",["misse... |
# | [("ENST00000616016.5","Ensembl","mRNA","ENSG00000187634","SAMD11",["downs... |
# | [("ENST00000327044.7","Ensembl","mRNA","ENSG00000188976","NOC2L",["synony... |
# | [("ENST00000327044.7","Ensembl","mRNA","ENSG00000188976","NOC2L",["synony... |
# | [("ENST00000327044.7","Ensembl","mRNA","ENSG00000188976","NOC2L",["missen... |
# | [("ENST00000327044.7","Ensembl","mRNA","ENSG00000188976","NOC2L",["upstre... |
# | [("ENST00000338591.8","Ensembl","mRNA","ENSG00000187961","KLHL17",["synon... |
# | [("ENST00000338591.8","Ensembl","mRNA","ENSG00000187961","KLHL17",["downs... |
# | [("ENST00000338591.8","Ensembl","mRNA","ENSG00000187961","KLHL17",["downs... |
# | [("ENST00000379410.8","Ensembl","mRNA","ENSG00000187583","PLEKHN1",["syno... |
# +------------------------------------------------------------------------------+
#
# +------------------------------------------------------------------------------+
# | samples                                                                      |
# +------------------------------------------------------------------------------+
# | array<struct{genotype: str, variant_frequencies: array<float64>, total_de... |
# +------------------------------------------------------------------------------+
# | [("0/1",[2,85e-01],116,9,[83,33])]                                           |
# | [("0/1",[6,75e-01],83,3,[27,56])]                                            |
# | [("1/1",[1,00e+00],68,41,[0,68])]                                            |
# | [("0/1",[6,67e-01],102,6,[34,68])]                                           |
# | [("1/1",[7,31e-01],93,3,[25,68])]                                            |
# | [("0/1",[7,06e-01],17,3,[5,12])]                                             |
# | [("1/1",[1,00e+00],44,56,[0,44])]                                            |
# | [("1/1",[1,00e+00],39,54,[0,39])]                                            |
# | [("1/1",[1,00e+00],44,52,[0,44])]                                            |
# | [("1/1",[1,00e+00],44,52,[0,44])]                                            |
# | [("1/1",[1,00e+00],61,54,[0,61])]                                            |
# | [("0/1",[5,09e-01],55,37,[27,28])]                                           |
# | [("1/1",[1,00e+00],45,54,[0,45])]                                            |
# | [("1/1",[1,00e+00],67,43,[0,67])]                                            |
# | [("1/1",[1,00e+00],63,42,[0,63])]                                            |
# | [("1/1",[1,00e+00],51,60,[0,51])]                                            |
# | [("0/1",[4,80e-01],50,48,[26,24])]                                           |
# | [("1/1",[1,00e+00],66,49,[0,66])]                                            |
# | [("1/1",[1,00e+00],69,51,[0,69])]                                            |
# | [("0/1",[5,22e-01],69,48,[33,36])]                                           |
# +------------------------------------------------------------------------------+
#
# +---------------+------------+---------------+------------+
# | locus         | alleles    | max_gnomad_af | max_pop_af |
# +---------------+------------+---------------+------------+
# | locus<GRCh38> | array<str> |       float64 |    float64 |
# +---------------+------------+---------------+------------+
# | chr1:69081    | ["G","C"]  |      1,76e-02 |   3,10e-02 |
# | chr1:69270    | ["A","G"]  |      8,78e-01 |   9,96e-01 |
# | chr1:69511    | ["A","G"]  |      9,62e-01 |   1,00e+00 |
# | chr1:69897    | ["T","C"]  |      7,04e-01 |   6,99e-01 |
# | chr1:358121   | ["C","T"]  |            NA |         NA |
# | chr1:373232   | ["G","A"]  |            NA |         NA |
# | chr1:924024   | ["C","G"]  |      9,44e-01 |   9,74e-01 |
# | chr1:924310   | ["C","G"]  |      9,78e-01 |   9,79e-01 |
# | chr1:924321   | ["C","G"]  |      9,86e-01 |   9,79e-01 |
# | chr1:924533   | ["A","G"]  |      9,54e-01 |   9,80e-01 |
# | chr1:942451   | ["T","C"]  |      1,00e+00 |   1,00e+00 |
# | chr1:946247   | ["G","A"]  |      6,21e-01 |   6,58e-01 |
# | chr1:952421   | ["A","G"]  |      9,43e-01 |   9,65e-01 |
# | chr1:953259   | ["T","C"]  |      9,43e-01 |   9,65e-01 |
# | chr1:953279   | ["T","C"]  |      9,43e-01 |   9,65e-01 |
# | chr1:961945   | ["G","C"]  |      9,26e-01 |   9,40e-01 |
# | chr1:965125   | ["G","C"]  |      2,64e-01 |   3,22e-01 |
# | chr1:966227   | ["C","G"]  |      8,41e-01 |   9,40e-01 |
# | chr1:966272   | ["A","G"]  |      1,00e+00 |   1,00e+00 |
# | chr1:970892   | ["A","C"]  |      1,31e-01 |   3,13e-01 |
# +---------------+------------+---------------+------------+
#
# +------------------------------------+-----------------------------+
# | canonical_transcript.transcript_id | canonical_transcript.source |
# +------------------------------------+-----------------------------+
# | str                                | str                         |
# +------------------------------------+-----------------------------+
# | "ENST00000642116.1"                | "Ensembl"                   |
# | "ENST00000641515.2"                | "Ensembl"                   |
# | "ENST00000641515.2"                | "Ensembl"                   |
# | "ENST00000641515.2"                | "Ensembl"                   |
# | "ENST00000450983.1"                | "Ensembl"                   |
# | "ENST00000455207.5"                | "Ensembl"                   |
# | "ENST00000417705.1"                | "Ensembl"                   |
# | "ENST00000417705.1"                | "Ensembl"                   |
# | "ENST00000417705.1"                | "Ensembl"                   |
# | "ENST00000417705.1"                | "Ensembl"                   |
# | "ENST00000616016.5"                | "Ensembl"                   |
# | "ENST00000616016.5"                | "Ensembl"                   |
# | "ENST00000327044.7"                | "Ensembl"                   |
# | "ENST00000327044.7"                | "Ensembl"                   |
# | "ENST00000327044.7"                | "Ensembl"                   |
# | "ENST00000327044.7"                | "Ensembl"                   |
# | "ENST00000338591.8"                | "Ensembl"                   |
# | "ENST00000338591.8"                | "Ensembl"                   |
# | "ENST00000338591.8"                | "Ensembl"                   |
# | "ENST00000379410.8"                | "Ensembl"                   |
# +------------------------------------+-----------------------------+
#
# +-------------------------------+------------------------------+
# | canonical_transcript.bio_type | canonical_transcript.gene_id |
# +-------------------------------+------------------------------+
# | str                           | str                          |
# +-------------------------------+------------------------------+
# | "lncRNA"                      | "ENSG00000290826"            |
# | "mRNA"                        | "ENSG00000186092"            |
# | "mRNA"                        | "ENSG00000186092"            |
# | "mRNA"                        | "ENSG00000186092"            |
# | "lncRNA"                      | "ENSG00000236601"            |
# | "lncRNA"                      | "ENSG00000290385"            |
# | "lncRNA"                      | "ENSG00000223764"            |
# | "lncRNA"                      | "ENSG00000223764"            |
# | "lncRNA"                      | "ENSG00000223764"            |
# | "lncRNA"                      | "ENSG00000223764"            |
# | "mRNA"                        | "ENSG00000187634"            |
# | "mRNA"                        | "ENSG00000187634"            |
# | "mRNA"                        | "ENSG00000188976"            |
# | "mRNA"                        | "ENSG00000188976"            |
# | "mRNA"                        | "ENSG00000188976"            |
# | "mRNA"                        | "ENSG00000188976"            |
# | "mRNA"                        | "ENSG00000187961"            |
# | "mRNA"                        | "ENSG00000187961"            |
# | "mRNA"                        | "ENSG00000187961"            |
# | "mRNA"                        | "ENSG00000187583"            |
# +-------------------------------+------------------------------+
#
# +---------------------------+----------------------------------------+
# | canonical_transcript.hgnc | canonical_transcript.consequences      |
# +---------------------------+----------------------------------------+
# | str                       | array<str>                             |
# +---------------------------+----------------------------------------+
# | "ENSG00000290826"         | ["downstream_gene_variant"]            |
# | "OR4F5"                   | ["synonymous_variant"]                 |
# | "OR4F5"                   | ["missense_variant"]                   |
# | "OR4F5"                   | ["synonymous_variant"]                 |
# | "ENSG00000236601"         | ["upstream_gene_variant"]              |
# | "ENSG00000290385"         | ["non_coding_transcript_exon_variant"] |
# | "LINC02593"               | ["upstream_gene_variant"]              |
# | "LINC02593"               | ["upstream_gene_variant"]              |
# | "LINC02593"               | ["upstream_gene_variant"]              |
# | "LINC02593"               | ["upstream_gene_variant"]              |
# | "SAMD11"                  | ["missense_variant"]                   |
# | "SAMD11"                  | ["downstream_gene_variant"]            |
# | "NOC2L"                   | ["synonymous_variant"]                 |
# | "NOC2L"                   | ["synonymous_variant"]                 |
# | "NOC2L"                   | ["missense_variant"]                   |
# | "NOC2L"                   | ["upstream_gene_variant"]              |
# | "KLHL17"                  | ["synonymous_variant"]                 |
# | "KLHL17"                  | ["downstream_gene_variant"]            |
# | "KLHL17"                  | ["downstream_gene_variant"]            |
# | "PLEKHN1"                 | ["synonymous_variant"]                 |
# +---------------------------+----------------------------------------+
#
# +-----------------------------+-----------------------------------+
# | canonical_transcript.impact | canonical_transcript.is_canonical |
# +-----------------------------+-----------------------------------+
# | str                         |                              bool |
# +-----------------------------+-----------------------------------+
# | "modifier"                  |                              True |
# | "low"                       |                              True |
# | "moderate"                  |                              True |
# | "low"                       |                              True |
# | "modifier"                  |                              True |
# | "modifier"                  |                              True |
# | "modifier"                  |                              True |
# | "modifier"                  |                              True |
# | "modifier"                  |                              True |
# | "modifier"                  |                              True |
# | "moderate"                  |                              True |
# | "modifier"                  |                              True |
# | "low"                       |                              True |
# | "low"                       |                              True |
# | "moderate"                  |                              True |
# | "modifier"                  |                              True |
# | "low"                       |                              True |
# | "modifier"                  |                              True |
# | "modifier"                  |                              True |
# | "low"                       |                              True |
# +-----------------------------+-----------------------------------+
#
# +------------------------------------------------------------------------------+
# | all_consequences                                                             |
# +------------------------------------------------------------------------------+
# | set<str>                                                                     |
# +------------------------------------------------------------------------------+
# | {"downstream_gene_variant","synonymous_variant"}                             |
# | {"synonymous_variant"}                                                       |
# | {"missense_variant"}                                                         |
# | {"synonymous_variant"}                                                       |
# | {"non_coding_transcript_exon_variant","upstream_gene_variant"}               |
# | {"non_coding_transcript_exon_variant","upstream_gene_variant"}               |
# | {"5_prime_UTR_variant","intron_variant","non_coding_transcript_variant","... |
# | {"5_prime_UTR_variant","intron_variant","non_coding_transcript_variant","... |
# | {"5_prime_UTR_variant","intron_variant","non_coding_transcript_variant","... |
# | {"intron_variant","non_coding_transcript_variant","synonymous_variant","u... |
# | {"downstream_gene_variant","missense_variant","non_coding_transcript_exon... |
# | {"downstream_gene_variant","non_coding_transcript_exon_variant","synonymo... |
# | {"downstream_gene_variant","non_coding_transcript_exon_variant","synonymo... |
# | {"downstream_gene_variant","non_coding_transcript_exon_variant","synonymo... |
# | {"downstream_gene_variant","missense_variant","non_coding_transcript_exon... |
# | {"non_coding_transcript_exon_variant","synonymous_variant","upstream_gene... |
# | {"downstream_gene_variant","synonymous_variant","upstream_gene_variant"}     |
# | {"downstream_gene_variant","upstream_gene_variant"}                          |
# | {"downstream_gene_variant","upstream_gene_variant"}                          |
# | {"downstream_gene_variant","non_coding_transcript_exon_variant","synonymo... |
# +------------------------------------------------------------------------------+
#
# +---------------------------------------+
# | genes                                 |
# +---------------------------------------+
# | set<str>                              |
# +---------------------------------------+
# | {"ENSG00000290826","OR4F5"}           |
# | {"OR4F5"}                             |
# | {"OR4F5"}                             |
# | {"OR4F5"}                             |
# | {"ENSG00000228463","ENSG00000236601"} |
# | {"ENSG00000290385"}                   |
# | {"LINC02593","LOC107985728","SAMD11"} |
# | {"LINC02593","LOC107985728","SAMD11"} |
# | {"LINC02593","LOC107985728","SAMD11"} |
# | {"LINC02593","LOC107985728","SAMD11"} |
# | {"NOC2L","SAMD11"}                    |
# | {"NOC2L","SAMD11"}                    |
# | {"NOC2L"}                             |
# | {"NOC2L"}                             |
# | {"NOC2L"}                             |
# | {"KLHL17","NOC2L","PLEKHN1"}          |
# | {"KLHL17","PLEKHN1"}                  |
# | {"KLHL17","PLEKHN1"}                  |
# | {"KLHL17","PLEKHN1"}                  |
# | {"PERM1","PLEKHN1"}                   |
# +---------------------------------------+
# showing top 20 rows
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Row fields:
#     'chromosome': str
#     'position': int32
#     'ref': str
#     'alt': str
#     'vid': str
#     'hgvsg': str
#     'variant_type': str
#     'begin': int32
#     'end': int32
#     'filters': str
#     'mapping_quality': float64
#     'fisher_strand_bias': float64
#     'quality': float64
#     'cytogenetic_band': str
#     'phylop_score': float64
#     'phylop_primate_score': float64
#     'gerp_score': float64
#     'dann_score': float64
#     'rsid': str
#     'gnomad_af': float64
#     'gnomad_ac': int32
#     'gnomad_an': int32
#     'gnomad_hc': int32
#     'gnomad_afr_af': float64
#     'gnomad_amr_af': float64
#     'gnomad_eas_af': float64
#     'gnomad_fin_af': float64
#     'gnomad_nfe_af': float64
#     'gnomad_asj_af': float64
#     'gnomad_sas_af': float64
#     'gnomad_oth_af': float64
#     'gnomad_failed_filter': bool
#     'gnomad_exome_af': float64
#     'gnomad_exome_ac': int32
#     'gnomad_exome_an': int32
#     'gnomad_exome_hc': int32
#     'gnomad_exome_failed_filter': bool
#     'topmed_af': float64
#     'topmed_ac': int32
#     'topmed_an': int32
#     'topmed_hc': int32
#     'topmed_failed_filter': bool
#     'clinvar_variant_type': str
#     'clinvar_significance': str
#     'clinvar_id': str
#     'n_transcripts': int32
#     'transcripts': array<struct {
#         transcript_id: str,
#         source: str,
#         bio_type: str,
#         gene_id: str,
#         hgnc: str,
#         consequences: array<str>,
#         impact: str,
#         is_canonical: bool
#     }>
#     'samples': array<struct {
#         genotype: str,
#         variant_frequencies: array<float64>,
#         total_depth: int32,
#         genotype_quality: int32,
#         allele_depths: array<int32>
#     }>
#     'locus': locus<GRCh38>
#     'alleles': array<str>
#     'max_gnomad_af': float64
#     'max_pop_af': float64
#     'canonical_transcript': struct {
#         transcript_id: str,
#         source: str,
#         bio_type: str,
#         gene_id: str,
#         hgnc: str,
#         consequences: array<str>,
#         impact: str,
#         is_canonical: bool
#     }
#     'all_consequences': set<str>
#     'genes': set<str>
# ----------------------------------------
# Key: ['locus', 'alleles']
# ----------------------------------------

# %%
ht = ht.flatten()
ht.describe()
# Out:
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Row fields:
#     'chromosome': str
#     'position': int32
#     'ref': str
#     'alt': str
#     'vid': str
#     'hgvsg': str
#     'variant_type': str
#     'begin': int32
#     'end': int32
#     'filters': str
#     'mapping_quality': float64
#     'fisher_strand_bias': float64
#     'quality': float64
#     'cytogenetic_band': str
#     'phylop_score': float64
#     'phylop_primate_score': float64
#     'gerp_score': float64
#     'dann_score': float64
#     'rsid': str
#     'gnomad_af': float64
#     'gnomad_ac': int32
#     'gnomad_an': int32
#     'gnomad_hc': int32
#     'gnomad_afr_af': float64
#     'gnomad_amr_af': float64
#     'gnomad_eas_af': float64
#     'gnomad_fin_af': float64
#     'gnomad_nfe_af': float64
#     'gnomad_asj_af': float64
#     'gnomad_sas_af': float64
#     'gnomad_oth_af': float64
#     'gnomad_failed_filter': bool
#     'gnomad_exome_af': float64
#     'gnomad_exome_ac': int32
#     'gnomad_exome_an': int32
#     'gnomad_exome_hc': int32
#     'gnomad_exome_failed_filter': bool
#     'topmed_af': float64
#     'topmed_ac': int32
#     'topmed_an': int32
#     'topmed_hc': int32
#     'topmed_failed_filter': bool
#     'clinvar_variant_type': str
#     'clinvar_significance': str
#     'clinvar_id': str
#     'n_transcripts': int32
#     'transcripts': array<struct {
#         transcript_id: str,
#         source: str,
#         bio_type: str,
#         gene_id: str,
#         hgnc: str,
#         consequences: array<str>,
#         impact: str,
#         is_canonical: bool
#     }>
#     'samples': array<struct {
#         genotype: str,
#         variant_frequencies: array<float64>,
#         total_depth: int32,
#         genotype_quality: int32,
#         allele_depths: array<int32>
#     }>
#     'locus': locus<GRCh38>
#     'alleles': array<str>
#     'max_gnomad_af': float64
#     'max_pop_af': float64
#     'canonical_transcript.transcript_id': str
#     'canonical_transcript.source': str
#     'canonical_transcript.bio_type': str
#     'canonical_transcript.gene_id': str
#     'canonical_transcript.hgnc': str
#     'canonical_transcript.consequences': array<str>
#     'canonical_transcript.impact': str
#     'canonical_transcript.is_canonical': bool
#     'all_consequences': set<str>
#     'genes': set<str>
# ----------------------------------------
# Key: []
# ----------------------------------------

# %%
es_host = 'localhost'
es_port = 9200
es_index = 'fiocruz_variants'
hl.export_elasticsearch(
    ht,
    host=es_host,
    port=es_port,
    index=es_index,
    index_type='_doc',
    block_size=10000,
)
# Out:
# Config Map(es.nodes -> localhost, es.port -> 9200, es.batch.size.entries -> 10000, es.index.auto.create -> true)
# [Stage 4:========================================================>(83 + 1) / 84]

# %%
def explore_hail_table(ht: hl.Table):
    """
    Comprehensive exploration and testing of a Hail Table
    
    Args:
        ht (hl.Table): Hail Table to explore
    """
    print("="*80)
    print("HAIL TABLE EXPLORATION AND TESTING")
    print("="*80)
    
    # Basic info
    print("\n2. BASIC STATISTICS")
    print("-" * 80)
    n_variants = ht.count()
    print(f"   Total variants: {n_variants:,}")
    print(f"   Key fields: {ht.key}")
    
    # Schema
    print("\n3. SCHEMA OVERVIEW")
    print("-" * 80)
    ht.describe()
    
    # Field names
    print("\n4. ALL FIELD NAMES")
    print("-" * 80)
    fields = list(ht.row)
    for i, field in enumerate(fields, 1):
        print(f"   {i:2d}. {field}")
    
    # Sample data - first 5 rows
    print("\n5. SAMPLE DATA (First 5 variants)")
    print("-" * 80)
    sample_df = ht.head(5).to_pandas()
    print(sample_df[['chromosome', 'position', 'ref', 'alt', 'vid', 'rsid']].to_string())
    
    # Chromosome distribution
    print("\n6. CHROMOSOME DISTRIBUTION")
    print("-" * 80)
    chrom_counts = ht.group_by(ht.chromosome).aggregate(n=hl.agg.count()).collect()
    chrom_df = pd.DataFrame(chrom_counts).sort_values('chromosome')
    print(chrom_df.to_string(index=False))
    
    # Variant type distribution
    print("\n7. VARIANT TYPE DISTRIBUTION")
    print("-" * 80)
    var_types = ht.group_by(ht.variant_type).aggregate(n=hl.agg.count()).collect()
    var_type_df = pd.DataFrame(var_types).sort_values('n', ascending=False)
    print(var_type_df.to_string(index=False))
    
    # gnomAD frequency statistics
    print("\n8. GNOMAD ALLELE FREQUENCY STATISTICS")
    print("-" * 80)
    gnomad_stats = ht.aggregate(hl.struct(
        total_variants=hl.agg.count(),
        with_gnomad_af=hl.agg.count_where(hl.is_defined(ht.gnomad_af)),
        with_gnomad_exome_af=hl.agg.count_where(hl.is_defined(ht.gnomad_exome_af)),
        mean_gnomad_af=hl.agg.mean(ht.gnomad_af),
        median_gnomad_af=hl.agg.approx_median(ht.gnomad_af),
        max_gnomad_af=hl.agg.max(ht.gnomad_af),
    ))
    print(f"   Total variants: {gnomad_stats.total_variants:,}")
    print(f"   With gnomAD genome AF: {gnomad_stats.with_gnomad_af:,}")
    print(f"   With gnomAD exome AF: {gnomad_stats.with_gnomad_exome_af:,}")
    print(f"   Mean gnomAD AF: {gnomad_stats.mean_gnomad_af:.6f}" if gnomad_stats.mean_gnomad_af else "   Mean gnomAD AF: N/A")
    print(f"   Median gnomAD AF: {gnomad_stats.median_gnomad_af:.6f}" if gnomad_stats.median_gnomad_af else "   Median gnomAD AF: N/A")
    print(f"   Max gnomAD AF: {gnomad_stats.max_gnomad_af:.6f}" if gnomad_stats.max_gnomad_af else "   Max gnomAD AF: N/A")
    
    # Frequency bins
    print("\n9. GNOMAD AF FREQUENCY BINS")
    print("-" * 80)
    freq_bins = ht.aggregate(hl.struct(
        rare_0_0001=hl.agg.count_where((ht.max_gnomad_af > 0) & (ht.max_gnomad_af <= 0.0001)),
        rare_0_001=hl.agg.count_where((ht.max_gnomad_af > 0.0001) & (ht.max_gnomad_af <= 0.001)),
        low_freq_0_01=hl.agg.count_where((ht.max_gnomad_af > 0.001) & (ht.max_gnomad_af <= 0.01)),
        common_0_05=hl.agg.count_where((ht.max_gnomad_af > 0.01) & (ht.max_gnomad_af <= 0.05)),
        very_common=hl.agg.count_where(ht.max_gnomad_af > 0.05),
        no_data=hl.agg.count_where(~hl.is_defined(ht.max_gnomad_af)),
    ))
    print(f"   Ultra-rare (AF ≤ 0.0001): {freq_bins.rare_0_0001:,}")
    print(f"   Rare (0.0001 < AF ≤ 0.001): {freq_bins.rare_0_001:,}")
    print(f"   Low freq (0.001 < AF ≤ 0.01): {freq_bins.low_freq_0_01:,}")
    print(f"   Common (0.01 < AF ≤ 0.05): {freq_bins.common_0_05:,}")
    print(f"   Very common (AF > 0.05): {freq_bins.very_common:,}")
    print(f"   No gnomAD data: {freq_bins.no_data:,}")
    
    # Transcript statistics
    print("\n10. TRANSCRIPT STATISTICS")
    print("-" * 80)
    transcript_stats = ht.aggregate(hl.struct(
        with_transcripts=hl.agg.count_where(ht.n_transcripts > 0),
        total_transcripts=hl.agg.sum(ht.n_transcripts),
        with_canonical=hl.agg.count_where(hl.is_defined(ht.canonical_transcript)),
        mean_transcripts=hl.agg.mean(ht.n_transcripts),
        max_transcripts=hl.agg.max(ht.n_transcripts),
    ))
    print(f"   Variants with transcripts: {transcript_stats.with_transcripts:,}")
    print(f"   Total transcript annotations: {transcript_stats.total_transcripts:,}")
    print(f"   Variants with canonical transcript: {transcript_stats.with_canonical:,}")
    print(f"   Mean transcripts per variant: {transcript_stats.mean_transcripts:.2f}")
    print(f"   Max transcripts per variant: {transcript_stats.max_transcripts}")
    
    # ClinVar statistics
    print("\n11. CLINVAR ANNOTATIONS")
    print("-" * 80)
    clinvar_stats = ht.aggregate(hl.struct(
        with_clinvar=hl.agg.count_where(hl.is_defined(ht.clinvar_significance)),
        total=hl.agg.count(),
    ))
    print(f"   Variants with ClinVar: {clinvar_stats.with_clinvar:,}")
    print(f"   Percentage: {100 * clinvar_stats.with_clinvar / clinvar_stats.total:.2f}%")
    
    # Conservation scores
    print("\n12. CONSERVATION SCORE STATISTICS")
    print("-" * 80)
    conservation_stats = ht.aggregate(hl.struct(
        phylop_mean=hl.agg.mean(ht.phylop_score),
        phylop_max=hl.agg.max(ht.phylop_score),
        gerp_mean=hl.agg.mean(ht.gerp_score),
        gerp_max=hl.agg.max(ht.gerp_score),
    ))
    print(f"   PhyloP mean: {conservation_stats.phylop_mean:.3f}" if conservation_stats.phylop_mean else "   PhyloP mean: N/A")
    print(f"   PhyloP max: {conservation_stats.phylop_max:.3f}" if conservation_stats.phylop_max else "   PhyloP max: N/A")
    print(f"   GERP mean: {conservation_stats.gerp_mean:.3f}" if conservation_stats.gerp_mean else "   GERP mean: N/A")
    print(f"   GERP max: {conservation_stats.gerp_max:.3f}" if conservation_stats.gerp_max else "   GERP max: N/A")
    
    # Gene statistics
    print("\n13. GENE STATISTICS")
    print("-" * 80)
    gene_stats = ht.aggregate(hl.struct(
        variants_with_genes=hl.agg.count_where(hl.len(ht.genes) > 0),
    ))
    # Count unique genes by converting set to array and aggregating
    unique_genes_count = ht.aggregate(
        hl.len(hl.agg.explode(lambda gene: hl.agg.collect_as_set(gene), hl.array(ht.genes)))
    )
    print(f"   Variants with gene annotations: {gene_stats.variants_with_genes:,}")
    print(f"   Unique genes: {unique_genes_count:,}")
    
    # Top consequences
    print("\n14. TOP 10 CONSEQUENCES")
    print("-" * 80)
    consequences_ht = ht.explode(ht.all_consequences)
    top_consequences = (consequences_ht
                       .group_by(consequences_ht.all_consequences)
                       .aggregate(n=hl.agg.count())
                       .order_by(hl.desc('n'))
                       .head(10)
                       .collect())
    for i, row in enumerate(top_consequences, 1):
        print(f"   {i:2d}. {row.all_consequences}: {row.n:,}")
    
    # Example queries
    print("\n15. EXAMPLE VARIANT LOOKUPS")
    print("-" * 80)
    
    # Get a few interesting variants
    # Common variant
    common = ht.filter(ht.max_gnomad_af > 0.1).head(1).collect()
    if common:
        v = common[0]
        print(f"\n   Common variant (AF > 0.1):")
        print(f"   {v.chromosome}:{v.position} {v.ref}>{v.alt}")
        print(f"   rsID: {v.rsid}")
        print(f"   gnomAD AF: {v.gnomad_af:.4f}" if v.gnomad_af else "   gnomAD AF: N/A")
        print(f"   Genes: {', '.join(v.genes) if v.genes else 'N/A'}")
    
    # Rare variant
    rare = ht.filter((ht.max_gnomad_af > 0) & (ht.max_gnomad_af < 0.001)).head(1).collect()
    if rare:
        v = rare[0]
        print(f"\n   Rare variant (AF < 0.001):")
        print(f"   {v.chromosome}:{v.position} {v.ref}>{v.alt}")
        print(f"   gnomAD AF: {v.gnomad_af:.6f}" if v.gnomad_af else "   gnomAD AF: N/A")
        print(f"   Consequences: {', '.join(list(v.all_consequences)) if v.all_consequences else 'N/A'}")
    
    # Variant with ClinVar
    clinvar_var = ht.filter(hl.is_defined(ht.clinvar_significance)).head(1).collect()
    if clinvar_var:
        v = clinvar_var[0]
        print(f"\n   ClinVar variant:")
        print(f"   {v.chromosome}:{v.position} {v.ref}>{v.alt}")
        print(f"   ClinVar significance: {v.clinvar_significance}")
        print(f"   ClinVar ID: {v.clinvar_id}")
    
    print("\n" + "="*80)
    print("TESTING COMPLETE!")
    print("="*80)

# %%
explore_hail_table(ht)
# Out:
# ================================================================================
# HAIL TABLE EXPLORATION AND TESTING
# ================================================================================
#
# 2. BASIC STATISTICS
# --------------------------------------------------------------------------------
#    Total variants: 30,487
#    Key fields: <StructExpression of type struct{locus: locus<GRCh38>, alleles: array<str>}>
#
# 3. SCHEMA OVERVIEW
# --------------------------------------------------------------------------------
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Row fields:
#     'chromosome': str
#     'position': int32
#     'ref': str
#     'alt': str
#     'vid': str
#     'hgvsg': str
#     'variant_type': str
#     'begin': int32
#     'end': int32
#     'filters': str
#     'mapping_quality': float64
#     'fisher_strand_bias': float64
#     'quality': float64
#     'cytogenetic_band': str
#     'phylop_score': float64
#     'phylop_primate_score': float64
#     'gerp_score': float64
#     'dann_score': float64
#     'rsid': str
#     'gnomad_af': float64
#     'gnomad_ac': int32
#     'gnomad_an': int32
#     'gnomad_hc': int32
#     'gnomad_afr_af': float64
#     'gnomad_amr_af': float64
#     'gnomad_eas_af': float64
#     'gnomad_fin_af': float64
#     'gnomad_nfe_af': float64
#     'gnomad_asj_af': float64
#     'gnomad_sas_af': float64
#     'gnomad_oth_af': float64
#     'gnomad_failed_filter': bool
#     'gnomad_exome_af': float64
#     'gnomad_exome_ac': int32
#     'gnomad_exome_an': int32
#     'gnomad_exome_hc': int32
#     'gnomad_exome_failed_filter': bool
#     'topmed_af': float64
#     'topmed_ac': int32
#     'topmed_an': int32
#     'topmed_hc': int32
#     'topmed_failed_filter': bool
#     'clinvar_significance': str
#     'clinvar_id': str
#     'n_transcripts': int32
#     'transcripts': array<struct {
#         transcript_id: str,
#         source: str,
#         bio_type: str,
#         gene_id: str,
#         hgnc: str,
#         consequences: array<str>,
#         impact: str,
#         is_canonical: bool
#     }>
#     'samples': array<struct {
#         genotype: str,
#         variant_frequencies: array<float64>,
#         total_depth: int32,
#         genotype_quality: int32,
#         allele_depths: array<int32>
#     }>
#     'locus': locus<GRCh38>
#     'alleles': array<str>
#     'max_gnomad_af': float64
#     'max_pop_af': float64
#     'canonical_transcript': struct {
#         transcript_id: str,
#         source: str,
#         bio_type: str,
#         gene_id: str,
#         hgnc: str,
#         consequences: array<str>,
#         impact: str,
#         is_canonical: bool
#     }
#     'all_consequences': set<str>
#     'genes': set<str>
# ----------------------------------------
# Key: ['locus', 'alleles']
# ----------------------------------------
#
# 4. ALL FIELD NAMES
# --------------------------------------------------------------------------------
#     1. chromosome
#     2. position
#     3. ref
#     4. alt
#     5. vid
#     6. hgvsg
#     7. variant_type
#     8. begin
#     9. end
#    10. filters
#    11. mapping_quality
#    12. fisher_strand_bias
#    13. quality
#    14. cytogenetic_band
#    15. phylop_score
#    16. phylop_primate_score
#    17. gerp_score
#    18. dann_score
#    19. rsid
#    20. gnomad_af
#    21. gnomad_ac
#    22. gnomad_an
#    23. gnomad_hc
#    24. gnomad_afr_af
#    25. gnomad_amr_af
#    26. gnomad_eas_af
#    27. gnomad_fin_af
#    28. gnomad_nfe_af
#    29. gnomad_asj_af
#    30. gnomad_sas_af
#    31. gnomad_oth_af
#    32. gnomad_failed_filter
#    33. gnomad_exome_af
#    34. gnomad_exome_ac
#    35. gnomad_exome_an
#    36. gnomad_exome_hc
#    37. gnomad_exome_failed_filter
#    38. topmed_af
#    39. topmed_ac
#    40. topmed_an
#    41. topmed_hc
#    42. topmed_failed_filter
#    43. clinvar_significance
#    44. clinvar_id
#    45. n_transcripts
#    46. transcripts
#    47. samples
#    48. locus
#    49. alleles
#    50. max_gnomad_af
#    51. max_pop_af
#    52. canonical_transcript
#    53. all_consequences
#    54. genes
#
# 5. SAMPLE DATA (First 5 variants)
# --------------------------------------------------------------------------------
#   chromosome  position ref alt           vid  rsid
# 0       chr1     69081   G   C   1-69081-G-C  <NA>
# 1       chr1     69270   A   G   1-69270-A-G  <NA>
# 2       chr1     69511   A   G   1-69511-A-G  <NA>
# 3       chr1     69897   T   C   1-69897-T-C  <NA>
# 4       chr1    358121   C   T  1-358121-C-T  <NA>
#
# 6. CHROMOSOME DISTRIBUTION
# --------------------------------------------------------------------------------
# [Stage 5:==================================>                     (51 + 13) / 84]
# chromosome    n
#       chr1 3036
#      chr10 1168
#      chr11 2140
#      chr12 1460
#      chr13  605
#      chr14 1105
#      chr15 1008
#      chr16 1348
#      chr17 1810
#      chr18  501
#      chr19 2453
#       chr2 2040
#      chr20  698
#      chr21  418
#      chr22  811
#       chr3 1433
#       chr4 1203
#       chr5 1373
#       chr6 1669
#       chr7 1507
#       chr8 1037
#       chr9 1244
#       chrX  417
#       chrY    3
#
# 7. VARIANT TYPE DISTRIBUTION
# --------------------------------------------------------------------------------
#     n variant_type
# 29008          SNV
#   759     deletion
#   718    insertion
#     1          MNV
#     1       delins
#
# 8. GNOMAD ALLELE FREQUENCY STATISTICS
# --------------------------------------------------------------------------------
#    Total variants: 30,487
#    With gnomAD genome AF: 29,915
#    With gnomAD exome AF: 28,146
#    Mean gnomAD AF: 0.447809
#    Median gnomAD AF: 0.422766
#    Max gnomAD AF: 1.000000
#
# 9. GNOMAD AF FREQUENCY BINS
# --------------------------------------------------------------------------------
#    Ultra-rare (AF ≤ 0.0001): 504
#    Rare (0.0001 < AF ≤ 0.001): 346
#    Low freq (0.001 < AF ≤ 0.01): 713
#    Common (0.01 < AF ≤ 0.05): 1,267
#    Very common (AF > 0.05): 27,152
#    No gnomAD data: 349
#
# 10. TRANSCRIPT STATISTICS
# --------------------------------------------------------------------------------
#    Variants with transcripts: 30,362
#    Total transcript annotations: 388,623
#    Variants with canonical transcript: 30,201
#    Mean transcripts per variant: 12.75
#    Max transcripts per variant: 402
#
# 11. CLINVAR ANNOTATIONS
# --------------------------------------------------------------------------------
#    Variants with ClinVar: 9,154
#    Percentage: 30.03%
#
# 12. CONSERVATION SCORE STATISTICS
# --------------------------------------------------------------------------------
#    PhyloP mean: -0.527
#    PhyloP max: 1.200
#    GERP mean: -2.095
#    GERP max: 8.050
#
# 13. GENE STATISTICS
# --------------------------------------------------------------------------------
#    Variants with gene annotations: 30,362
#    Unique genes: 17,458
#
# 14. TOP 10 CONSEQUENCES
# --------------------------------------------------------------------------------
#     1. downstream_gene_variant: 13,197
#     2. missense_variant: 12,800
#     3. non_coding_transcript_exon_variant: 12,784
#     4. synonymous_variant: 12,754
#     5. intron_variant: 12,161
#     6. upstream_gene_variant: 11,418
#     7. non_coding_transcript_variant: 7,330
#     8. 3_prime_UTR_variant: 5,627
#     9. 5_prime_UTR_variant: 1,681
#    10. splice_region_variant: 846
#
# 15. EXAMPLE VARIANT LOOKUPS
# --------------------------------------------------------------------------------
#
#    Common variant (AF > 0.1):
#    chr1:69270 A>G
#    rsID: None
#    gnomAD AF: 0.6286
#    Genes: OR4F5
#
#    Rare variant (AF < 0.001):
#    chr1:1041200 C>T
#    gnomAD AF: 0.000013
#    Consequences: missense_variant, upstream_gene_variant, non_coding_transcript_exon_variant
#
#    ClinVar variant:
#    chr1:942451 T>C
#    ClinVar significance: benign;uncertain significance;uncertain significance;benign
#    ClinVar ID: VCV001166513.9;VCV003249251.1;RCV004814516.1;RCV001514847.8
#
# ================================================================================
# TESTING COMPLETE!
# ================================================================================

# %%
def query_examples(ht: hl.Table):
    """
    Examples of useful queries you can run
    
    Args:
        ht (hl.Table): Hail Table to query
    """
    print("\n" + "="*80)
    print("EXAMPLE QUERIES")
    print("="*80)
    
    # 1. Filter by frequency
    print("\n1. Get rare variants (AF < 0.01)")
    rare_variants = ht.filter(
        (ht.max_gnomad_af > 0) & (ht.max_gnomad_af < 0.01)
    )
    print(f"   Found {rare_variants.count():,} rare variants")
    
    # 2. Filter by gene
    print("\n2. Get variants in specific gene (e.g., first gene in dataset)")
    first_gene = ht.filter(hl.len(ht.genes) > 0).head(1).collect()[0].genes
    if first_gene:
        gene_name = list(first_gene)[0]
        gene_variants = ht.filter(ht.genes.contains(gene_name))
        print(f"   Gene: {gene_name}")
        print(f"   Variants: {gene_variants.count()}")
    
    # 3. Filter by consequence
    print("\n3. Get missense variants")
    missense = ht.filter(ht.all_consequences.contains('missense_variant'))
    print(f"   Found {missense.count():,} missense variants")
    
    # 4. Filter by ClinVar pathogenic
    print("\n4. Get pathogenic variants")
    pathogenic = ht.filter(
        hl.is_defined(ht.clinvar_significance) &
        ht.clinvar_significance.contains('Pathogenic')
    )
    print(f"   Found {pathogenic.count():,} pathogenic variants")
    
    # 5. Filter by conservation
    print("\n5. Get highly conserved variants (PhyloP > 2)")
    conserved = ht.filter(ht.phylop_score > 2)
    print(f"   Found {conserved.count():,} highly conserved variants")
    
    # 6. Complex filter
    print("\n6. Complex filter: Rare + missense + conserved")
    complex_filter = ht.filter(
        (ht.max_gnomad_af < 0.01) &
        ht.all_consequences.contains('missense_variant') &
        (ht.phylop_score > 2)
    )
    print(f"   Found {complex_filter.count():,} variants")
    
    print("\n" + "="*80)

# %%
query_examples(ht)
# Out:
# ================================================================================
# EXAMPLE QUERIES
# ================================================================================
#
# 1. Get rare variants (AF < 0.01)
#    Found 1,563 rare variants
#
# 2. Get variants in specific gene (e.g., first gene in dataset)
#    Gene: ENSG00000290826
#    Variants: 1
#
# 3. Get missense variants
#    Found 12,800 missense variants
#
# 4. Get pathogenic variants
#    Found 0 pathogenic variants
#
# 5. Get highly conserved variants (PhyloP > 2)
#    Found 0 highly conserved variants
#
# 6. Complex filter: Rare + missense + conserved
#    Found 0 variants
#
# ================================================================================
